# %% [markdown]
# jetzt sim

# %%
from src.sourcefunktionensamples import sample_metallicity, ms_lifetimes_years, stellar_endpoints, sample_salpeter

# %% [markdown]
# Monte-Carlo-Simulation

# %% [markdown]
# population ziehen und sicherstellen

# %%
N = 100000
import numpy as np  
masses = sample_salpeter(N)
masses = np.atleast_1d(masses)
metallicities = sample_metallicity(N)
metallicities = np.atleast_1d(metallicities)

# %% [markdown]
# einzelstern physik anwenden :P

# %%
lifetimes = np.array([
    ms_lifetimes_years(masses, metallicities)
    for masses, metallicities in zip(masses, metallicities)
])

endstates = np.array([
    stellar_endpoints(m) 
    for m in masses
    ])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       1 lifetimes = np.array([
#       2     ms_lifetimes_years(masses, metallicities)
#       3     for masses, metallicities in zip(masses, metallicities)
#       4 ])
#       6 endstates = np.array([
# ----> 7     stellar_endpoints(m)
#       8     for m in masses
#       9     ])
#
# File c:\Users\Lea\Documents\supernovaesimulation\src\sourcefunktionensamples.py:48, in stellar_endpoints(masses)
#      40 """
#      41 Determine the stellar endpoints based on mass and metallicity.
#      42 For simplicity, we classify endpoints as:
#    (...)     45     - Black Hole (BH) for M ≥ 20 M_sun
#      46 """
#      47 endpoints = []
# ---> 48 for m in masses:
#      49     if m < 8.0:
#      50         endpoints.append('WD')
#
# TypeError: 'numpy.float64' object is not iterable

# %%
from src.supernovamodels import core_collapse_SN_type, is_type_ia
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from src.supernovamodels import core_collapse_SN_type, is_type_ia
#
# ModuleNotFoundError: No module named 'src.supernovamodels'

# %% [markdown]
# supernovaeeee

# %%
cc_sn_types = np.array([
    core_collapse_SN_type(m)
    for m in masses
    ])  

ia_flags = np.array([
    is_type_ia(m)
    for m in masses
    ])  

sn_types = np.where(ia_flags, "Type Ia", cc_sn_types)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 cc_sn_types = np.array([
# ----> 2     core_collapse_SN_type(m)
#       3     for m in masses
#       4     ])
#       6 ia_flags = np.array([
#       7     is_type_ia(m)
#       8     for m in masses
#       9     ])
#      11 sn_types = np.where(ia_flags, "Type Ia", cc_sn_types)
#
# NameError: name 'core_collapse_SN_type' is not defined
