# %% [markdown]
# jetzt sim

# %%
import sys
import os
for path in sys.path:
    print(path)
sys.path.append(os.path.abspath('src'))
# Out:
# c:\Users\Lea\Documents\uni\simtools\.conda\python311.zip
# c:\Users\Lea\Documents\uni\simtools\.conda\DLLs
# c:\Users\Lea\Documents\uni\simtools\.conda\Lib
# c:\Users\Lea\Documents\uni\simtools\.conda
#
# c:\Users\Lea\Documents\uni\simtools\.conda\Lib\site-packages
# c:\Users\Lea\Documents\uni\simtools\.conda\Lib\site-packages\win32
# c:\Users\Lea\Documents\uni\simtools\.conda\Lib\site-packages\win32\lib
# c:\Users\Lea\Documents\uni\simtools\.conda\Lib\site-packages\Pythonwin
# c:\Users\Lea\Documents\supernovaesimulation\notebooks\src

# %%
# Import from the src directory
from src.sourcefunktionensamples import sample_metallicity, ms_lifetimes_years, stellar_endpoints
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Import from the src directory
# ----> 2 from src.sourcefunktionensamples import sample_metallicity, ms_lifetimes_years, stellar_endpoints
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# Monte-Carlo-Simulation

# %%
N = 100000
sample_salpeter
